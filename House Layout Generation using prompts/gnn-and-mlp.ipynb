# %%
# !python /kaggle/input/hpgm-code/HPGM-master/bbox_gcn_Lited_postprocessing/main.py --cfg /kaggle/input/hpgm-code/HPGM-master/bbox_gcn_Lited_postprocessing/cfg/layout.yml --gpu '0'
# Out:
# Using config:
# {'BBOX': {'LR': 0.002, 'WEIGHT_DECAY': 0.0005},
#  'CONFIG_NAME': '3stages',
#  'CUDA': True,
#  'DATASET_NAME': 'layout',
#  'DATA_DIR': '/kaggle/input/hpgm-layout/layout',
#  'EVAL': {'BATCH_SIZE': 1,
#           'BOX_NET': 'box_net_best.pth',
#           'GCN': 'gcn_best.pth',
#           'GRAPH_PRE_NET': 'graph_prediction_net_best.pth',
#           'OUTPUT_DIR': '/kaggle/working/output_bbox_gcn/layout_3stages_2020_03_07_11_53_57'},
#  'FIXED_NOISE': False,
#  'FLOOR_PLAN': {'WIN_DOOR': True},
#  'FURNITURE': False,
#  'GCN': {'LR': 0.002, 'WEIGHT_DECAY': 0.0005},
#  'GPU_ID': '0',
#  'GRAPH': {'LR': 0.0002, 'WEIGHT_DECAY': 0.0},
#  'IMAGE_CHANNEL': 1,
#  'ROOM_CLASSES': 9,
#  'TEST': {'B_EXAMPLE': True, 'SAMPLE_NUM': 30000},
#  'TRAIN': {'BATCH_SIZE': 256,
#            'BOX_NET': '',
#            'CHECK_POINT_INTERVAL': 10,
#            'COEFF': {'BBOX_LOSS': 200.0,
#                      'COLOR_LOSS': 0.0,
#                      'KL': 2.0,
# ...

# %%
# !python /kaggle/input/hpgm-code/HPGM-master/bbox_gcn_Lited_postprocessing/main.py --cfg /kaggle/input/hpgm-code/HPGM-master/bbox_gcn_Lited_postprocessing/cfg/layout_test.yml --gpu '0'
# Out:
# Using config:
# {'BBOX': {'LR': 0.002, 'WEIGHT_DECAY': 0.0005},
#  'CONFIG_NAME': '3stages',
#  'CUDA': True,
#  'DATASET_NAME': 'layout',
#  'DATA_DIR': '/kaggle/input/hpgm-layout/layout',
#  'EVAL': {'BATCH_SIZE': 1,
#           'BOX_NET': 'box_net_best.pth',
#           'GCN': 'gcn_best.pth',
#           'GRAPH_PRE_NET': 'graph_prediction_net_best.pth',
#           'OUTPUT_DIR': '/kaggle/working/output_bbox_gcn/layout_3stages_2024_04_04_04_38_56'},
#  'FIXED_NOISE': False,
#  'FLOOR_PLAN': {'WIN_DOOR': True},
#  'FURNITURE': False,
#  'GCN': {'LR': 0.002, 'WEIGHT_DECAY': 0.0005},
#  'GPU_ID': '0',
#  'GRAPH': {'LR': 0.002, 'WEIGHT_DECAY': 0.0005},
#  'IMAGE_CHANNEL': 1,
#  'ROOM_CLASSES': 9,
#  'TEST': {'B_EXAMPLE': True, 'SAMPLE_NUM': 30000},
#  'TRAIN': {'BATCH_SIZE': 256,
#            'BOX_NET': '',
#            'CHECK_POINT_INTERVAL': 10,
#            'COEFF': {'BBOX_LOSS': 300.0,
#                      'COLOR_LOSS': 0.0,
#                      'KL': 2.0,
# ...
