# %% [markdown]
# There is a bedroom with 20 m width and 20 m length and located in the north of the apartment.
# There is a kitchen with 20 m width and 20 m length and located in the south of the apartment.
# There is a bathroom with 1 m width and 1 m length and located in the west of the apartment.
#
# There is a living room which is 40 m long and 30 m wide facing north. Then there is a bedroom of 20 m length and 20 m width facing south. There is also a balcony of 10 m width and 15 m length which is at the west. There is also a study room of 20 m length and 10 m width in the south east.
#
# I want a kitchen that is 20 m wide and 10 m long with a attached bathroom facing north west.
#
# I have a bedroom that is 20 m wide and 20 m long and is present in the north of the apartment
# can you try to validate this layout?
#
# I have a bedroom that is 20 m wide and 20 m long and is present in the north of the apartment. I also would like to have a kitchen that is 20 m long and 20 m wide which is near the south west of the apartment. There is also a bathroom in the north west which is 10 m long and wide. And finally there is a living room with 30 m wide and 30 m long in the east

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def generate_bounding_box(min_x, max_x, min_y, max_y):
    x1 = random.uniform(min_x, max_x)
    y1 = random.uniform(min_y, max_y)
    x2 = random.uniform(min_x, max_x)
    y2 = random.uniform(min_y, max_y)
    
    x_min, x_max = min(x1, x2), max(x1, x2)
    y_min, y_max = min(y1, y2), max(y1, y2)
    
    return (x_min, y_min, x_max, y_max)

def visualize_bounding_box(bounding_box, min_x, max_x, min_y, max_y):
    fig, ax = plt.subplots()
    
    # Plot bounding box
    x_min, y_min, x_max, y_max = bounding_box
    width = x_max - x_min
    height = y_max - y_min
    rect = patches.Rectangle((x_min, y_min), width, height, linewidth=2, edgecolor='r', facecolor='none')
    ax.add_patch(rect)
    
    ax.set_xlim(min_x, max_x)
    ax.set_ylim(min_y, max_y)
    ax.set_aspect('equal', adjustable='box')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_title('Bounding Box with Direction')
    plt.grid(True)
    plt.show()


# Define boundaries
min_x = 0
max_x = 100
min_y = 0
max_y = 100

# Generate bounding box coordinates
num_boxes = 5
bounding_boxes = [generate_bounding_box(min_x, max_x, min_y, max_y) for _ in range(num_boxes)]

# Visualize the bounding boxes
visualize_bounding_boxes(bounding_boxes, min_x, max_x, min_y, max_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 47
#      44 bounding_boxes = [generate_bounding_box(min_x, max_x, min_y, max_y) for _ in range(num_boxes)]
#      46 # Visualize the bounding boxes
# ---> 47 visualize_bounding_boxes(bounding_boxes, min_x, max_x, min_y, max_y)
#
# NameError: name 'visualize_bounding_boxes' is not defined

# %% [markdown]
# ### working with direction

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.patches as patches


def generate_bounding_box_with_direction(min_x, max_x, min_y, max_y, direction):
    # Calculate center of the overall boundary
    center_x = (max_x + min_x) / 2
    center_y = (max_y + min_y) / 2
    
    # Generate random width and height
    width = random.uniform(0, max_x - min_x)
    height = random.uniform(0, max_y - min_y)
    
    # Adjust coordinates based on direction
    if direction == "North":
        y1 = center_y
        y2 = y1 + height
        x1 = center_x - width / 2
        x2 = center_x + width / 2
    elif direction == "North east":
        y1 = center_y
        y2 = y1 + height
        x1 = center_x
        x2 = center_x + width
    elif direction == "East":
        y1 = center_y - height / 2
        y2 = center_y + height / 2
        x1 = center_x
        x2 = center_x + width
    elif direction == "South east":
        y1 = center_y - height
        y2 = center_y
        x1 = center_x
        x2 = center_x + width
    elif direction == "South":
        y1 = center_y - height
        y2 = center_y
        x1 = center_x - width / 2
        x2 = center_x + width / 2
    elif direction == "South west":
        y1 = center_y - height
        y2 = center_y
        x1 = center_x - width
        x2 = center_x
    elif direction == "West":
        y1 = center_y - height / 2
        y2 = center_y + height / 2
        x1 = center_x - width
        x2 = center_x
    elif direction == "North west":
        y1 = center_y
        y2 = y1 + height
        x1 = center_x - width
        x2 = center_x
    
    return (x1, y1, x2, y2)

def visualize_bounding_box(bounding_box, min_x, max_x, min_y, max_y):
    fig, ax = plt.subplots()
    
    # Plot bounding box
    x_min, y_min, x_max, y_max = bounding_box
    width = x_max - x_min
    height = y_max - y_min
    rect = patches.Rectangle((x_min, y_min), width, height, linewidth=1, edgecolor='r', facecolor='none')
    ax.add_patch(rect)
    
    ax.set_xlim(min_x, max_x)
    ax.set_ylim(min_y, max_y)
    ax.set_aspect('equal', adjustable='box')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_title('Bounding Box with Direction')
    plt.grid(True)
    plt.show()

# Define boundaries
min_x = 0
max_x = 100
min_y = 0
max_y = 100

# Generate bounding box coordinates with direction
direction = "South east"
bounding_box = generate_bounding_box_with_direction(min_x, max_x, min_y, max_y, direction)

# Visualize the bounding box
visualize_bounding_box(bounding_box, min_x, max_x, min_y, max_y)

# %%
import random
def visualize_bounding_box(bounding_box, min_x, max_x, min_y, max_y):
    fig, ax = plt.subplots()
    
    # Plot bounding box
    x_min, y_min, x_max, y_max = bounding_box
    width = x_max - x_min
    height = y_max - y_min
    rect = patches.Rectangle((x_min, y_min), width, height, linewidth=2, edgecolor='r', facecolor='none')
    ax.add_patch(rect)
    
    ax.set_xlim(min_x, max_x)
    ax.set_ylim(min_y, max_y)
    ax.set_aspect('equal', adjustable='box')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_title('Bounding Box with Direction')
    plt.grid(True)
    plt.show()
    
def generate_bounding_box_with_direction(min_x, max_x, min_y, max_y, direction):
    # Calculate center of the overall boundary
    center_x = (max_x + min_x) / 2
    center_y = (max_y + min_y) / 2
    
    # Generate random width and height
    width = random.uniform(0, max_x - min_x)
    height = random.uniform(0, max_y - min_y)
    
    # Adjust coordinates based on direction
    if direction == "North":
        y1 = center_y
        y2 = min(center_y + height, max_y)
        x1 = max(center_x - width / 2, min_x)
        x2 = min(center_x + width / 2, max_x)
    elif direction == "North east":
        y1 = center_y
        y2 = min(center_y + height, max_y)
        x1 = center_x
        x2 = min(center_x + width, max_x)
    elif direction == "East":
        y1 = max(center_y - height / 2, min_y)
        y2 = min(center_y + height / 2, max_y)
        x1 = center_x
        x2 = min(center_x + width, max_x)
    elif direction == "South east":
        y1 = max(center_y - height, min_y)
        y2 = center_y
        x1 = center_x
        x2 = min(center_x + width, max_x)
    elif direction == "South":
        y1 = max(center_y - height, min_y)
        y2 = center_y
        x1 = max(center_x - width / 2, min_x)
        x2 = min(center_x + width / 2, max_x)
    elif direction == "South west":
        y1 = max(center_y - height, min_y)
        y2 = center_y
        x1 = max(center_x - width, min_x)
        x2 = center_x
    elif direction == "West":
        y1 = max(center_y - height / 2, min_y)
        y2 = min(center_y + height / 2, max_y)
        x1 = max(center_x - width, min_x)
        x2 = center_x
    elif direction == "North west":
        y1 = center_y
        y2 = min(center_y + height, max_y)
        x1 = max(center_x - width, min_x)
        x2 = center_x
    
    print(x1,y1,x2,y2)
    return (x1, y1, x2, y2)

# Define boundaries
min_x = 0
max_x = 100
min_y = 0
max_y = 100

# Generate bounding box coordinates with direction
direction = "South east"
bounding_box = generate_bounding_box_with_direction(min_x, max_x, min_y, max_y, direction)

# Visualize the bounding box
visualize_bounding_box(bounding_box, min_x, max_x, min_y, max_y)
# Out:
# 50.0 41.40315899457468 100 50.0

# %% [markdown]
# ### checking with custom width and height (working)

# %%
def visualize_bounding_box(bounding_box, min_x, max_x, min_y, max_y):
    fig, ax = plt.subplots()
    
    # Plot bounding box
    x_min, y_min, x_max, y_max = bounding_box
    width = x_max - x_min
    height = y_max - y_min
    rect = patches.Rectangle((x_min, y_min), width, height, linewidth=2, edgecolor='r', facecolor='none')
    ax.add_patch(rect)
    
    ax.set_xlim(min_x, max_x)
    ax.set_ylim(min_y, max_y)
    ax.set_aspect('equal', adjustable='box')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_title('Bounding Box with Direction')
    plt.grid(True)
    plt.show()
    
def generate_bounding_box_with_direction(min_x, max_x, min_y, max_y, direction, width, height):
    # Calculate center of the overall boundary
    center_x = (max_x + min_x) / 2
    center_y = (max_y + min_y) / 2
    
    # Adjust coordinates based on direction
    if direction == "North":
        y1 = center_y
        y2 = min(center_y + height, max_y)
        x1 = max(center_x - width / 2, min_x)
        x2 = min(center_x + width / 2, max_x)
    elif direction == "North east":
        y1 = center_y
        y2 = min(center_y + height, max_y)
        x1 = center_x
        x2 = min(center_x + width, max_x)
    elif direction == "East":
        y1 = max(center_y - height / 2, min_y)
        y2 = min(center_y + height / 2, max_y)
        x1 = center_x
        x2 = min(center_x + width, max_x)
    elif direction == "South east":
        y1 = max(center_y - height, min_y)
        y2 = center_y
        x1 = center_x
        x2 = min(center_x + width, max_x)
    elif direction == "South":
        y1 = max(center_y - height, min_y)
        y2 = center_y
        x1 = max(center_x - width / 2, min_x)
        x2 = min(center_x + width / 2, max_x)
    elif direction == "South west":
        y1 = max(center_y - height, min_y)
        y2 = center_y
        x1 = max(center_x - width, min_x)
        x2 = center_x
    elif direction == "West":
        y1 = max(center_y - height / 2, min_y)
        y2 = min(center_y + height / 2, max_y)
        x1 = max(center_x - width, min_x)
        x2 = center_x
    elif direction == "North west":
        y1 = center_y
        y2 = min(center_y + height, max_y)
        x1 = max(center_x - width, min_x)
        x2 = center_x
    
    return (x1, y1, x2, y2)

# Define boundaries
min_x = 0
max_x = 100
min_y = 0
max_y = 100

# Generate bounding box coordinates with direction, width, and height
direction = "North west"
width = 40
height = 20
bounding_box = generate_bounding_box_with_direction(min_x, max_x, min_y, max_y, direction, width, height)

# Visualize the bounding box
visualize_bounding_box(bounding_box, min_x, max_x, min_y, max_y)

# %% [markdown]
# ### printing multiple generated boxes together

# %%
# Define boundaries
min_x = 0
max_x = 100
min_y = 0
max_y = 100

# Initialize list to store bounding box coordinates
bounding_boxes = []

# Generate bounding box coordinates for each box
num_boxes = 5
for _ in range(num_boxes):
    # Randomly choose a direction
    direction = random.choice(["North", "North east", "East", "South east", "South", "South west", "West", "North west"])
    
    # Generate random width and height
    width = random.uniform(10, 30)  # Adjust width range as needed
    height = random.uniform(10, 30)  # Adjust height range as needed
    
    # Generate bounding box coordinates with direction, width, and height
    bounding_box = generate_bounding_box_with_direction(min_x, max_x, min_y, max_y, direction, width, height)
    
    # Add bounding box coordinates to the list
    bounding_boxes.append(bounding_box)

# Visualize all bounding boxes together
fig, ax = plt.subplots()

# Plot all bounding boxes
for bbox in bounding_boxes:
    x_min, y_min, x_max, y_max = bbox
    width = x_max - x_min
    height = y_max - y_min
    rect = patches.Rectangle((x_min, y_min), width, height, linewidth=2, edgecolor='r', facecolor='none')
    ax.add_patch(rect)

# Set plot boundaries and labels
ax.set_xlim(min_x, max_x)
ax.set_ylim(min_y, max_y)
ax.set_aspect('equal', adjustable='box')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Multiple Bounding Boxes in the Same Layout')
plt.grid(True)
plt.show()

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.patches as patches


def visualize_bounding_box(bounding_box, min_x, max_x, min_y, max_y, color='r'):
    fig, ax = plt.subplots()
    
    # Plot bounding box with specified color
    x_min, y_min, x_max, y_max = bounding_box
    width = x_max - x_min
    height = y_max - y_min
    rect = patches.Rectangle((x_min, y_min), width, height, linewidth=2, edgecolor=color, facecolor='None')
    ax.add_patch(rect)
    
    ax.set_xlim(min_x, max_x)
    ax.set_ylim(min_y, max_y)
    ax.set_aspect('equal', adjustable='box')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_title('Bounding Box with Direction')
    plt.grid(True)
    plt.show()

def generate_bounding_box_with_direction(min_x, max_x, min_y, max_y, direction, width, height):
    # Calculate center of the overall boundary
    center_x = (max_x + min_x) / 2
    center_y = (max_y + min_y) / 2
    
    # Adjust coordinates based on direction
    if direction == "North":
        y1 = center_y
        y2 = min(center_y + height, max_y)
        x1 = max(center_x - width / 2, min_x)
        x2 = min(center_x + width / 2, max_x)
    elif direction == "North east":
        y1 = center_y
        y2 = min(center_y + height, max_y)
        x1 = center_x
        x2 = min(center_x + width, max_x)
    elif direction == "East":
        y1 = max(center_y - height / 2, min_y)
        y2 = min(center_y + height / 2, max_y)
        x1 = center_x
        x2 = min(center_x + width, max_x)
    elif direction == "South east":
        y1 = max(center_y - height, min_y)
        y2 = center_y
        x1 = center_x
        x2 = min(center_x + width, max_x)
    elif direction == "South":
        y1 = max(center_y - height, min_y)
        y2 = center_y
        x1 = max(center_x - width / 2, min_x)
        x2 = min(center_x + width / 2, max_x)
    elif direction == "South west":
        y1 = max(center_y - height, min_y)
        y2 = center_y
        x1 = max(center_x - width, min_x)
        x2 = center_x
    elif direction == "West":
        y1 = max(center_y - height / 2, min_y)
        y2 = min(center_y + height / 2, max_y)
        x1 = max(center_x - width, min_x)
        x2 = center_x
    elif direction == "North west":
        y1 = center_y
        y2 = min(center_y + height, max_y)
        x1 = max(center_x - width, min_x)
        x2 = center_x
    
    return (x1, y1, x2, y2)

def check_center_collision(new_center, existing_centers, min_distance):
    """
    Check if the new center collides with any existing center.
    """
    for center in existing_centers:
        distance = ((new_center[0] - center[0]) ** 2 + (new_center[1] - center[1]) ** 2) ** 0.5
        if distance < min_distance:
            return True
    return False


def generate_non_overlapping_bounding_boxes(min_x, max_x, min_y, max_y, num_boxes, min_width, max_width, min_height, max_height, min_distance):
    bounding_boxes = []
    centers = []
    
    for _ in range(num_boxes):
        # Generate random width and height
        width = random.uniform(min_width, max_width)
        height = random.uniform(min_height, max_height)
        
        # Generate bounding box coordinates with direction, width, and height
        while True:
            # Randomly choose a direction
            direction = random.choice(["North", "North east", "East", "South east", "South", "South west", "West", "North west"])
            
            # Generate bounding box coordinates with direction, width, and height
            bounding_box = generate_bounding_box_with_direction(min_x, max_x, min_y, max_y, direction, width, height)
            
            # Calculate center of the bounding box
            center_x = (bounding_box[0] + bounding_box[2]) / 2
            center_y = (bounding_box[1] + bounding_box[3]) / 2
            new_center = (center_x, center_y)
            
            # Check if the new center collides with existing centers
            if not check_center_collision(new_center, centers, min_distance):
                bounding_boxes.append(bounding_box)
                centers.append(new_center)
                break
    
    return bounding_boxes


# Define boundaries
min_x = 0
max_x = 100
min_y = 0
max_y = 100

# Define parameters for generating non-overlapping bounding boxes
num_boxes = 3
min_width = 10
max_width = 30
min_height = 10
max_height = 30
min_distance = 10  # Minimum distance between centers

# Generate non-overlapping bounding boxes
bounding_boxes = generate_non_overlapping_bounding_boxes(min_x, max_x, min_y, max_y, num_boxes, min_width, max_width, min_height, max_height, min_distance)

# Colors for each bounding box
colors = ['r', 'g', 'b', 'c', 'm']

# Visualize all bounding boxes together
fig, ax = plt.subplots()

# Plot all bounding boxes with different colors
for bbox, color in zip(bounding_boxes, colors):
    x_min, y_min, x_max, y_max = bbox
    width = x_max - x_min
    height = y_max - y_min
    rect = patches.Rectangle((x_min, y_min), width, height, linewidth=2, edgecolor=color, facecolor='None')
    ax.add_patch(rect)

# Set plot boundaries and labels
ax.set_xlim(min_x, max_x)
ax.set_ylim(min_y, max_y)
ax.set_aspect('equal', adjustable='box')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Non-Overlapping Bounding Boxes with Different Colors')
plt.grid(True)
plt.show()

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def visualize_bounding_boxes(bounding_boxes, min_x, max_x, min_y, max_y):
    fig, ax = plt.subplots()
    room_colors = {}  # To store room colors for legend
    
    for room in bounding_boxes:
        bounding_box = room['bbox']
        color = room['color']
        room_name = room['name']
        
        # Plot bounding box with specified color
        x_min, y_min, x_max, y_max = bounding_box
        width = x_max - x_min
        height = y_max - y_min
        rect = patches.Rectangle((x_min, y_min), width, height, linewidth=2, edgecolor=color, facecolor=color, label=room_name)
        ax.add_patch(rect)
        
        # Add room name as annotation
        center_x = (x_min + x_max) / 2
        center_y = (y_min + y_max) / 2
        #ax.text(center_x, center_y, room_name, horizontalalignment='center', verticalalignment='center', fontsize=10, color='black')
        
        # Store room colors for legend
        room_colors[room_name] = color
    
    ax.set_xlim(min_x, max_x)
    ax.set_ylim(min_y, max_y)
    ax.set_aspect('equal', adjustable='box')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_title('Non-Overlapping Bounding Boxes')
    
    # Add legend
    handles = [patches.Patch(color=color, label=room_name) for room_name, color in room_colors.items()]
    plt.legend(handles=handles, loc='upper right', title='Rooms', fontsize='small')
    
    plt.grid(True)
    plt.show()



def generate_bounding_box_with_direction(min_x, max_x, min_y, max_y, direction, width, height):
    # Calculate center of the overall boundary
    center_x = (max_x + min_x) / 2
    center_y = (max_y + min_y) / 2
    
    # Adjust coordinates based on direction
    if direction == "North":
        y1 = center_y
        y2 = min(center_y + height, max_y)
        x1 = max(center_x - width / 2, min_x)
        x2 = min(center_x + width / 2, max_x)
    elif direction == "North east":
        y1 = center_y
        y2 = min(center_y + height, max_y)
        x1 = center_x
        x2 = min(center_x + width, max_x)
    elif direction == "East":
        y1 = max(center_y - height / 2, min_y)
        y2 = min(center_y + height / 2, max_y)
        x1 = center_x
        x2 = min(center_x + width, max_x)
    elif direction == "South east":
        y1 = max(center_y - height, min_y)
        y2 = center_y
        x1 = center_x
        x2 = min(center_x + width, max_x)
    elif direction == "South":
        y1 = max(center_y - height, min_y)
        y2 = center_y
        x1 = max(center_x - width / 2, min_x)
        x2 = min(center_x + width / 2, max_x)
    elif direction == "South west":
        y1 = max(center_y - height, min_y)
        y2 = center_y
        x1 = max(center_x - width, min_x)
        x2 = center_x
    elif direction == "West":
        y1 = max(center_y - height / 2, min_y)
        y2 = min(center_y + height / 2, max_y)
        x1 = max(center_x - width, min_x)
        x2 = center_x
    elif direction == "North west":
        y1 = center_y
        y2 = min(center_y + height, max_y)
        x1 = max(center_x - width, min_x)
        x2 = center_x
    
    return (x1, y1, x2, y2)


def check_center_collision(new_center, existing_centers, min_distance):
    """
    Check if the new center collides with any existing center.
    """
    for center in existing_centers:
        distance = ((new_center[0] - center[0]) ** 2 + (new_center[1] - center[1]) ** 2) ** 0.5
        if distance < min_distance:
            return True
    return False


def generate_non_overlapping_bounding_boxes(room_data, min_x, max_x, min_y, max_y, min_distance):
    bounding_boxes = []
    centers = []
    
    for room in room_data:
        room_name = room['name']
        width = room['width']
        height = room['height']
        direction = room['direction']
        
        # Generate bounding box coordinates with direction, width, and height
        while True:
            # Generate bounding box coordinates with direction, width, and height
            bounding_box = generate_bounding_box_with_direction(min_x, max_x, min_y, max_y, direction, width, height)
            
            # Calculate center of the bounding box
            center_x = (bounding_box[0] + bounding_box[2]) / 2
            center_y = (bounding_box[1] + bounding_box[3]) / 2
            new_center = (center_x, center_y)
            
            # Check if the new center collides with existing centers
            if not check_center_collision(new_center, centers, min_distance):
                bounding_boxes.append({'bbox': bounding_box, 'color': room['color'], 'name': room_name})
                centers.append(new_center)
                break
    
    return bounding_boxes


# Define boundaries
min_x = 0
max_x = 100
min_y = 0
max_y = 100

room_data = [
    {'name': 'Living room', 'width': 10, 'height': 20, 'direction': 'North', 'color': 'r'},
    {'name': 'Bedroom', 'width': 20, 'height': 20, 'direction': 'North east', 'color': 'g'},
    {'name': 'Balcony', 'width': 20, 'height': 20, 'direction': 'East', 'color': 'b'},
    {'name': 'Kitchen', 'width': 20, 'height': 20, 'direction': 'South', 'color': 'c'},
    {'name': 'Bathroom', 'width': 20, 'height': 20, 'direction': 'South west', 'color': 'm'},
    {'name': 'Office', 'width': 10, 'height': 10, 'direction': 'West', 'color': 'y'}
]

min_distance = 10  # Minimum distance between centers

# Generate non-overlapping bounding boxes
bounding_boxes = generate_non_overlapping_bounding_boxes(room_data, min_x, max_x, min_y, max_y, min_distance)

# Visualize all bounding boxes together
visualize_bounding_boxes(bounding_boxes, min_x, max_x, min_y, max_y)
